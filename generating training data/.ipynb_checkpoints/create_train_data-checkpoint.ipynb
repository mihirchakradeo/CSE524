# %%
import glob
import pandas as pd
import numpy as np

# %%
not_wanted = set(["Greater", "Equal", "Pre", "Post", "Extrinsic-Pre", "Extrinsic-Post", "Assign", "Less", "OperationName", "Comparison"])

# %%
# This function builds a dictionary with all the words in the ann file as values and indices as their 
# corresponding variable names

def builddict(file):
    d = {}
    f = open(file, 'r')
    lines = f.readlines()
    for line in lines:
        line = line.strip()
        if line.startswith("T"):
                line = line.split("\t")[1:]
                entity = line[0].split(" ")[0]
                if entity not in not_wanted:
                    _, si, ei = line[0].split(" ")
                    if si not in d:
                        d[si] = []
                        d[si].append(str(entity)) 
                        d[si].append(str(line[1]))
    return d

# %%
# This function builds a listt of list for a given txt file, with the entries of the inner list being
# the words in the txt file and its corresponding tag (var/value)

def build_dataframe(file, d):
    df = []
    with open(file) as f:
        cindex = 0
        seen = False
        end = 0
        nonzerocount = 0
        temp = f.readlines()
        flag = False
        
        for line in temp:
            tempstr = ""
            
            if "DESCRIPTION" in line:
                flag = True
            for i,char in enumerate(line):
                i_inner = end+i
                if str(cindex) in d or seen and flag:
                    seen = True
                    tempstr += char
                    
                    if seen and str(cindex) in d and i_inner == cindex+int(len(d[str(cindex)][1])):
                        seen = False
                        # add to df
                        # check if var or val 
                        if d[str(cindex)][0] != "Value":
#                             df.append([tempstr[:-1], d[str(cindex)][0]])
                            df.append([tempstr[:-1], "Variable"])
                        else:
                            df.append([tempstr[:-1], d[str(cindex)][0]])
                        tempstr = ""
                        cindex = i_inner
                        nonzerocount += 1

                else:
                    if flag:
                        if char == " ":
                            df.append([tempstr, '0'])
                            tempstr = ""
                        else:
                            tempstr += char

                    cindex = i_inner

            end += len(line)
    return df,nonzerocount

# %%
# This cell generates the training data per file and appends to the data list

import os
from collections import defaultdict

EXTENSIONS = {'.ann', '.txt'}

directory = 'only ann'

grouped_files = defaultdict(int)

for f in os.listdir(directory):
    name, ext = os.path.splitext(os.path.join(directory, f))
    if ext in EXTENSIONS:
        grouped_files[name] += 1
data = []
totalcount = 0
tc2 = 0
for name in grouped_files:
    if grouped_files[name] == len(EXTENSIONS):
        filetxt = '{}.txt'.format(name)
        fileann = '{}.ann'.format(name)
#         print "*"*10,filetxt,fileann
        d = builddict(fileann)
        totalcount += len(d)
        df,nzc = build_dataframe(filetxt, d)
        tc2 += nzc
        data += df

# %%
# Converting the data list to pandas dataframe
dataframe = pd.DataFrame(data, columns=['entity', 'tag'])

# %%
# Run this cell to get rid of empty entries
dataframe['entity'].replace('', np.nan, inplace=True)
dataframe.dropna(inplace=True)

# %%
dataframe[dataframe['tag']!='0'].head()
# Out:
#                        entity       tag
# 62         current filehandle  Variable
# 65  named attribute directory  Variable
# 74       named attribute file     Value
# 92                 createmode  Variable
# 94                 EXCLUSIVE4     Value

# %%
# Writing train data to file
def write_to_csv(dataframe):
    dataframe.to_csv("train_data.csv")
# write_to_csv(dataframe)

# %%
# splitting row entry over spaces
df2 = []
sentence_id = 0

import re
import nltk

for index, row in dataframe.iterrows():
    for ele in row['entity'].split(" "):
#         s = re.sub(r'[^\w\s]','',ele)
        ele = re.sub('[(){},]', '', ele)
        ele2 = ele = re.sub('[(){},<>]', '', ele)
        token = nltk.word_tokenize(ele2)
        pos_tag = nltk.pos_tag(token)
        if pos_tag:
            pos_tag = pos_tag[0][1]
        else:
            pos_tag = "."
        df2.append([ele, row['tag'], sentence_id, pos_tag])
        if "<NULL>" in ele:
            sentence_id += 1
df2 = pd.DataFrame(df2, columns=['entity', 'tag', 'Sentence #', 'POS'])
df2.to_csv("train_data_3.csv")

# %%
df2[df2['tag']!='0']
# Out:
#                    entity       tag  Sentence #  POS
# 59                current  Variable           0   JJ
# 60             filehandle  Variable           0   NN
# 63                  named  Variable           0  VBN
# 64              attribute  Variable           0   NN
# 65              directory  Variable           0   NN
# 73                  named     Value           0  VBN
# 74              attribute     Value           0   NN
# 75                   file     Value           0   NN
# 91             createmode  Variable           0   NN
# 93             EXCLUSIVE4     Value           0   NN
# 96                current  Variable           0   JJ
# 97             filehandle  Variable           0   NN
# 100                 named     Value           0  VBN
# 101             attribute     Value           0   NN
# 102             directory     Value           0   NN
# 107                EINVAL     Value           0   NN
# 108                  NULL  Variable           0   NN
# 109            UNCHECKED4  Variable           0   NN
# 172            UNCHECKED4  Variable           0   NN
# 176              existing     Value           0  VBG
# 177                  file     Value           0   NN
# 179            attributes  Variable           0  NNS
# 182           createattrs     Value           0   NN
# 190                  size  Variable           0   NN
# 192                  zero     Value           0   NN
# 196              existing  Variable           0  VBG
# 197                  file  Variable           0   NN
# 202              GUARDED4  Variable           0   NN
# 224             duplicate     Value           0   NN
# 229         NFS4ERR_EXIST     Value           0   NN
# ...                   ...       ...         ...  ...
# 7523           filehandle  Variable           0   NN
# 7533         NFS4ERR_XDEV     Value           0   NN
# 7538                 NULL  Variable           0   NN
# 7541              current  Variable           0   JJ
# 7542           filehandle  Variable           0   NN
# 7555                saved  Variable           0  VBN
# 7556           filehandle  Variable           0   NN
# 7570      NFS4ERR_NOTSUPP     Value           0   NN
# 7571                 NULL  Variable           0   NN
# 7576              newname  Variable           0   NN
# 7586                saved  Variable           0  VBN
# 7587           filehandle  Variable           0   NN
# 7592        NFS4ERR_EXIST     Value           0   NN
# 7593                 NULL  Variable           0   NN
# 7612              current  Variable           0   JJ
# 7613           filehandle  Variable           0   NN
# 7615              stateid  Variable           0   NN
# 7616                 NULL  Variable           0   NN
# 8087        NFS4ERR_INVAL     Value           0   NN
# 8089    NFS4ERR_BAD_RANGE     Value           0   NN
# 8100                 NULL  Variable           0   NN
# 8102              success     Value           0   NN
# 8104              current  Variable           0   JJ
# 8105           filehandle  Variable           0   NN
# 8108                value  Variable           0   NN
# 8109                 NULL  Variable           0   NN
# 8135   NFS4ERR_LOCK_RANGE     Value           0   NN
# 8136                 NULL  Variable           0   NN
# 8230               client  Variable           0   NN
# 8233  OPEN_DELEGATE_WRITE     Value           0   NN
#
# [438 rows x 4 columns]

# %%
tags = list(set(df2["tag"].values))

# %%
et = df2['entity']

# %%
# adding pos tags
import nltk
text=nltk.word_tokenize("We are going out.Just you and me.")
print nltk.pos_tag(text)
# Out:
# ['We', 'are', 'going', 'out.Just', 'you', 'and', 'me', '.']
