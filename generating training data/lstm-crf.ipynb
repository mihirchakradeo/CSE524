# %%
import pandas as pd
import numpy as np

data = pd.read_csv("train_data_3.csv", names=['Word','Tag','Sentence #'], skiprows=1)

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
n_words = len(words); n_words
# Out:
# 1225

# %%
tags = list(set(data["Tag"].values))
n_tags = len(tags); n_tags
# Out:
# 3

# %%
tags
# Out:
# ['Variable', '0', 'Value']

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, t) for w, t in zip(s["Word"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)

# %%
sent = getter.get_next()

# %%
print(sent)
# Out:
# None

# %%
sentences = getter.sentences
print(sentences)
# Out:
# [[('16.16.5.', '0'), ('The', '0'), ('OPEN', '0'), ('operation', '0'), ('creates', '0'), ('and/or', '0'), ('opens', '0'), ('a', '0'), ('regular', '0'), ('file', '0'), ('in', '0'), ('a', '0'), ('directory', '0'), ('with', '0'), ('the', '0'), ('provided', '0'), ('name', '0'), ('<NULL>.', '0')], [('If', '0'), ('the', '0'), ('file', '0'), ('does', '0'), ('not', '0'), ('exist', '0'), ('at', '0'), ('the', '0'), ('server', '0'), ('and', '0'), ('creation', '0'), ('is', '0'), ('desired', '0'), ('specification', '0'), ('of', '0'), ('the', '0'), ('method', '0'), ('of', '0'), ('creation', '0'), ('is', '0'), ('provided', '0'), ('by', '0'), ('the', '0'), ('openhow', '0'), ('parameter', '0'), ('<NULL>.', '0')], [('The', '0'), ('client', '0'), ('has', '0'), ('the', '0'), ('choice', '0'), ('of', '0'), ('three', '0'), ('creation', '0'), ('methods:', '0'), ('UNCHECKED4', '0'), ('GUARDED4', '0'), ('or', '0'), ('EXCLUSIVE4', '0'), ('If', '0'), ('the', '0'), ('current', 'Variable'), ('filehandle', 'Variable'), ('is', '0'), ('a', '0'), ('named', 'Variable'), ('attribute', 'Variable'), ('directory', 'Variable'), ('OPEN', '0'), ('will', '0'), ('then', '0'), ('create', '0'), ('or', '0'), ('open', '0'), ('a', '0'), ('named', 'Value'), ('attribute', 'Value'), ('file', 'Value'), ('<NULL>.', '0')], [('Note', '0'), ('that', '0'), ('exclusive', '0'), ('create', '0'), ('of', '0'), ('a', '0'), ('named', '0'), ('attribute', '0'), ('is', '0'), ('not', '0'), ('supported', '0'), ('<NULL>.', '0')], [('If', '0'), ('the', '0'), ('createmode', 'Variable'), ('is', '0'), ('EXCLUSIVE4', 'Value'), ('and', '0'), ('the', '0'), ('current', 'Variable'), ('filehandle', 'Variable'), ('is', '0'), ('a', '0'), ('named', 'Value'), ('attribute', 'Value'), ('directory', 'Value'), ('the', '0'), ('server', '0'), ('will', '0'), ('return', '0'), ('EINVAL', 'Value'), ('<NULL>', 'Variable')], [('UNCHECKED4', 'Variable'), ('means', '0'), ('that', '0'), ('the', '0'), ('file', '0'), ('should', '0'), ('be', '0'), ('created', '0'), ('if', '0'), ('a', '0'), ('file', '0'), ('of', '0'), ('that', '0'), ('name', '0'), ('does', '0'), ('not', '0'), ('exist', '0'), ('and', '0'), ('encountering', '0'), ('an', '0'), ('existing', '0'), ('regular', '0'), ('file', '0'), ('of', '0'), ('that', '0'), ('name', '0'), ('is', '0'), ('not', '0'), ('an', '0'), ('error', '0'), ('<NULL>.', '0')], [('For', '0'), ('this', '0'), ('type', '0'), ('of', '0'), ('create', '0'), ('createattrs', '0'), ('specifies', '0'), ('the', '0'), ('initial', '0'), ('set', '0'), ('of', '0'), ('attributes', '0'), ('for', '0'), ('the', '0'), ('file', '0'), ('<NULL>.', '0')], [('The', '0'), ('set', '0'), ('of', '0'), ('attributes', '0'), ('may', '0'), ('include', '0'), ('any', '0'), ('writable', '0'), ('attribute', '0'), ('valid', '0'), ('for', '0'), ('regular', '0'), ('files', '0'), ('<NULL>.', '0')], [('When', '0'), ('an', '0'), ('UNCHECKED4', 'Variable'), ('create', '0'), ('encounters', '0'), ('an', '0'), ('existing', 'Value'), ('file', 'Value'), ('the', '0'), ('attributes', 'Variable'), ('specified', '0'), ('by', '0'), ('createattrs', 'Value'), ('are', '0'), ('not', '0'), ('used', '0'), ('except', '0'), ('that', '0'), ('when', '0'), ('a', '0'), ('size', 'Variable'), ('of', '0'), ('zero', 'Value'), ('is', '0'), ('specified', '0'), ('the', '0'), ('existing', 'Variable'), ('file', 'Variable'), ('is', '0'), ('truncated', '0'), ('<NULL>.', '0')], [('If', '0'), ('GUARDED4', 'Variable'), ('is', '0'), ('specified', '0'), ('the', '0'), ('server', '0'), ('checks', '0'), ('for', '0'), ('the', '0'), ('presence', '0'), ('of', '0'), ('a', '0'), ('duplicate', '0'), ('object', '0'), ('by', '0'), ('name', '0'), ('before', '0'), ('performing', '0'), ('the', '0'), ('create', '0'), ('<NULL>.', '0')], [('If', '0'), ('a', '0'), ('duplicate', 'Value'), ('exists', '0'), ('an', '0'), ('error', '0'), ('of', '0'), ('NFS4ERR_EXIST', 'Value'), ('is', '0'), ('returned', '0'), ('as', '0'), ('the', '0'), ('status', 'Variable'), ('<NULL>.', '0')], [('If', '0'), ('the', '0' ...

# %%
max_len = 75
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
word2idx["current"]
# Out:
# 97

# %%
tag2idx["0"]
# Out:
# 1

# %%
from keras.preprocessing.sequence import pad_sequences
X = [[word2idx[w[0]] for w in s] for s in sentences]
# Out:
# Using TensorFlow backend.

# %%
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=n_words)

# %%
y = [[tag2idx[w[1]] for w in s] for s in sentences]

# %%
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["0"])

# %%
from keras.utils import to_categorical

# %%
y = [to_categorical(i, num_classes=n_tags) for i in y]

# %%
from sklearn.model_selection import train_test_split

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.1)

# %%
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF

# %%
input = Input(shape=(max_len,))
model = Embedding(input_dim=n_words + 1, output_dim=20,
                  input_length=max_len, mask_zero=True)(input)  # 20-dim embedding
model = Bidirectional(LSTM(units=50, return_sequences=True,
                           recurrent_dropout=0.1))(model)  # variational biLSTM
model = TimeDistributed(Dense(50, activation="relu"))(model)  # a dense layer as suggested by neuralNer
crf = CRF(n_tags)  # CRF layer
out = crf(model)  # output

# %%
model = Model(input, out)

# %%
model.compile(optimizer="rmsprop", loss=crf.loss_function, metrics=[crf.accuracy])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 75)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 75, 20)            24520
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 75, 100)           28400
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 75, 50)            5050
# _________________________________________________________________
# crf_1 (CRF)                  (None, 75, 3)             168
# =================================================================
# Total params: 58,138
# Trainable params: 58,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_tr, np.array(y_tr), batch_size=32, epochs=20,
                    validation_split=0.1, verbose=1)
# Out:
# Train on 243 samples, validate on 27 samples
# Epoch 1/20
# 243/243 [==============================] - 6s 27ms/step - loss: 0.4374 - viterbi_acc: 0.9154 - val_loss: 0.0931 - val_viterbi_acc: 0.9867
# Epoch 2/20
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1006 - viterbi_acc: 0.9795 - val_loss: 0.0715 - val_viterbi_acc: 0.9867
# Epoch 3/20
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0996 - viterbi_acc: 0.9795 - val_loss: 0.0688 - val_viterbi_acc: 0.9867
# Epoch 4/20
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0949 - viterbi_acc: 0.9795 - val_loss: 0.0674 - val_viterbi_acc: 0.9867
# Epoch 5/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0931 - viterbi_acc: 0.9795 - val_loss: 0.0662 - val_viterbi_acc: 0.9867
# Epoch 6/20
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0888 - viterbi_acc: 0.9795 - val_loss: 0.0736 - val_viterbi_acc: 0.9867
# Epoch 7/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0851 - viterbi_acc: 0.9795 - val_loss: 0.0717 - val_viterbi_acc: 0.9867
# Epoch 8/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0813 - viterbi_acc: 0.9795 - val_loss: 0.0601 - val_viterbi_acc: 0.9867
# Epoch 9/20
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0761 - viterbi_acc: 0.9795 - val_loss: 0.0586 - val_viterbi_acc: 0.9867
# Epoch 10/20
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0719 - viterbi_acc: 0.9795 - val_loss: 0.0549 - val_viterbi_acc: 0.9867
# Epoch 11/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0693 - viterbi_acc: 0.9795 - val_loss: 0.0524 - val_viterbi_acc: 0.9867
# Epoch 12/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0660 - viterbi_acc: 0.9795 - val_loss: 0.0500 - val_viterbi_acc: 0.9867
# Epoch 13/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0634 - viterbi_acc: 0.9798 - val_loss: 0.0496 - val_viterbi_acc: 0.9867
# Epoch 14/20
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0598 - viterbi_acc: 0.9798 - val_loss: 0.0470 - val_viterbi_acc: 0.9867
# Epoch 15/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0585 - viterbi_acc: 0.9800 - val_loss: 0.0462 - val_viterbi_acc: 0.9867
# Epoch 16/20
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0559 - viterbi_acc: 0.9805 - val_loss: 0.0449 - val_viterbi_acc: 0.9867
# Epoch 17/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0527 - viterbi_acc: 0.9812 - val_loss: 0.0422 - val_viterbi_acc: 0.9867
# Epoch 18/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0499 - viterbi_acc: 0.9823 - val_loss: 0.0415 - val_viterbi_acc: 0.9867
# Epoch 19/20
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0488 - viterbi_acc: 0.9834 - val_loss: 0.0395 - val_viterbi_acc: 0.9877
# Epoch 20/20
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0449 - viterbi_acc: 0.9841 - val_loss: 0.0387 - val_viterbi_acc: 0.9877

# %%
hist = pd.DataFrame(history.history)

# %%
# import matplotlib.pyplot as plt
# plt.style.use("ggplot")
# plt.figure(figsize=(12,12))
# plt.plot(hist["acc"])
# plt.plot(hist["val_acc"])
# plt.show()

# %%
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report

# %%
test_pred = model.predict(X_te, verbose=1)
# Out:
# 31/31 [==============================] - 1s 24ms/step

# %%
idx2tag = {i: w for w, i in tag2idx.items()}

def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i].replace("PAD", "O"))
        out.append(out_i)
    return out
    
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_te)

# %%
print("F1-score: {:.1%}".format(f1_score(test_labels, pred_labels)))
# Out:
# F1-score: 47.2%

# %%
print(classification_report(test_labels, pred_labels))
# Out:
#              precision    recall  f1-score   support
#
#    Variable       0.67      0.22      0.33        18
#           0       0.71      0.45      0.56        55
#       Value       0.00      0.00      0.00         7
#
# avg / total       0.64      0.36      0.46        80

# %%
i = 30
p = model.predict(np.array([X_te[i]]))
p = np.argmax(p, axis=-1)
true = np.argmax(y_te[i], -1)
print("{:15}||{:5}||{}".format("Word", "True", "Pred"))
print(30 * "=")
length = 0
for w, t, pred in zip(X_te[i], true, p[0]):
    length+=1
    if w != 0:
        print("{:15}: {:5} {}".format(words[w-1], tags[t], tags[pred]))
# Out:
# Word           ||True ||Pred
# ==============================
# The            : 0     0
# server         : 0     0
# has            : 0     0
# two            : 0     0
# choices        : 0     0
# <NULL>.        : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
# ENDPAD         : 0     0
