# %%
import glob
import pandas as pd
import numpy as np

# %%
not_wanted = set(["Greater", "Equal", "Pre", "Post", "Extrinsic-Pre", "Extrinsic-Post", "Assign", "Less", "OperationName", "Comparison"])

# %%
# This function builds a dictionary with all the words in the ann file as values and indices as their 
# corresponding variable names

def builddict(file):
    d = {}
    f = open(file, 'r')
    lines = f.readlines()
    for line in lines:
        line = line.strip()
        if line.startswith("T"):
                line = line.split("\t")[1:]
                entity = line[0].split(" ")[0]
                if entity not in not_wanted:
                    _, si, ei = line[0].split(" ")
                    if si not in d:
                        d[si] = []
                        d[si].append(str(entity)) 
                        d[si].append(str(line[1]))
    return d

# %%
# This function builds a listt of list for a given txt file, with the entries of the inner list being
# the words in the txt file and its corresponding tag (var/value)

def build_dataframe(file, d):
    df = []
    with open(file) as f:
        cindex = 0
        seen = False
        end = 0
        nonzerocount = 0
        temp = f.readlines()
        flag = False
        
        for line in temp:
            tempstr = ""
            
            if "DESCRIPTION" in line:
                flag = True
            for i,char in enumerate(line):
                i_inner = end+i
                if str(cindex) in d or seen and flag:
                    seen = True
                    tempstr += char
                    
                    if seen and str(cindex) in d and i_inner == cindex+int(len(d[str(cindex)][1])):
                        seen = False
                        # add to df
                        # check if var or val 
                        if d[str(cindex)][0] != "Value":
#                             df.append([tempstr[:-1], d[str(cindex)][0]])
                            df.append([tempstr[:-1], "Variable"])
                        else:
                            df.append([tempstr[:-1], d[str(cindex)][0]])
                        tempstr = ""
                        cindex = i_inner
                        nonzerocount += 1

                else:
                    if flag:
                        if char == " ":
                            df.append([tempstr, '0'])
                            tempstr = ""
                        else:
                            tempstr += char

                    cindex = i_inner

            end += len(line)
    return df,nonzerocount

# %%
# This cell generates the training data per file and appends to the data list

import os
from collections import defaultdict

EXTENSIONS = {'.ann', '.txt'}

directory = 'only ann'

grouped_files = defaultdict(int)

for f in os.listdir(directory):
    name, ext = os.path.splitext(os.path.join(directory, f))
    if ext in EXTENSIONS:
        grouped_files[name] += 1
data = []
totalcount = 0
tc2 = 0
for name in grouped_files:
    if grouped_files[name] == len(EXTENSIONS):
        filetxt = '{}.txt'.format(name)
        fileann = '{}.ann'.format(name)
#         print "*"*10,filetxt,fileann
        d = builddict(fileann)
        totalcount += len(d)
        df,nzc = build_dataframe(filetxt, d)
        tc2 += nzc
        data += df

# %%
# Converting the data list to pandas dataframe
dataframe = pd.DataFrame(data, columns=['entity', 'tag'])

# %%
# Run this cell to get rid of empty entries
dataframe['entity'].replace('', np.nan, inplace=True)
dataframe.dropna(inplace=True)

# %%
dataframe[dataframe['tag']!='0']
# Out:
#                                entity       tag
# 62                 current filehandle  Variable
# 65          named attribute directory  Variable
# 74               named attribute file     Value
# 92                         createmode  Variable
# 94                         EXCLUSIVE4     Value
# 97                 current filehandle  Variable
# 100         named attribute directory     Value
# 106                            EINVAL     Value
# 107                            <NULL>  Variable
# 108                        UNCHECKED4  Variable
# 174                        UNCHECKED4  Variable
# 178                     existing file     Value
# 181                        attributes  Variable
# 184                       createattrs     Value
# 192                              size  Variable
# 194                              zero     Value
# 198                     existing file  Variable
# 204                          GUARDED4  Variable
# 227                         duplicate     Value
# 232                     NFS4ERR_EXIST     Value
# 237                            status  Variable
# 261                       (UNCHECKED4  Variable
# 263                          GUARDED4  Variable
# 267                         operation  Variable
# 269                        successful     Value
# 290                        EXCLUSIVE4  Variable
# 330                            object  Variable
# 350                            object  Variable
# 355                   stored verifier  Variable
# 358   verifier provided by the client  Variable
# ...                               ...       ...
# 7733               current filehandle  Variable
# 7746                 saved filehandle  Variable
# 7759                NFS4ERR_XDEV MUST     Value
# 7762                           <NULL>  Variable
# 7767                 saved filehandle  Variable
# 7774               current filehandle  Variable
# 7784                     NFS4ERR_XDEV     Value
# 7789                           <NULL>  Variable
# 7792               current filehandle  Variable
# 7805                 saved filehandle  Variable
# 7820                  NFS4ERR_NOTSUPP     Value
# 7821                           <NULL>  Variable
# 7826                          newname  Variable
# 7836                 saved filehandle  Variable
# 7842                    NFS4ERR_EXIST     Value
# 7843                           <NULL>  Variable
# 7863               current filehandle  Variable
# 7865                          stateid  Variable
# 7866                           <NULL>  Variable
# 8373                    NFS4ERR_INVAL     Value
# 8375                NFS4ERR_BAD_RANGE     Value
# 8387                           <NULL>  Variable
# 8389                          success     Value
# 8392               current filehandle  Variable
# 8395                            value  Variable
# 8396                           <NULL>  Variable
# 8423               NFS4ERR_LOCK_RANGE     Value
# 8424                           <NULL>  Variable
# 8521                           client  Variable
# 8524              OPEN_DELEGATE_WRITE     Value
#
# [310 rows x 2 columns]

# %%
# Writing train data to file
def write_to_csv(dataframe):
    dataframe.to_csv("train_data.csv")
# write_to_csv(dataframe)

# %%
# splitting row entry over spaces
df2 = []
sentence_id = 0

import re
for index, row in dataframe.iterrows():
    for ele in row['entity'].split(" "):
#         s = re.sub(r'[^\w\s]','',ele)
        ele = re.sub('[(){},]', '', ele)
        df2.append([ele, row['tag'], sentence_id])
        if "<NULL>" in ele:
            sentence_id += 1
df2 = pd.DataFrame(df2, columns=['entity', 'tag', 'Sentence #'])
df2.to_csv("train_data_3.csv")

# %%
df2[df2['tag']!='0']
# Out:
#                    entity       tag  Sentence #
# 59                current  Variable           2
# 60             filehandle  Variable           2
# 63                  named  Variable           2
# 64              attribute  Variable           2
# 65              directory  Variable           2
# 73                  named     Value           2
# 74              attribute     Value           2
# 75                   file     Value           2
# 91             createmode  Variable           4
# 93             EXCLUSIVE4     Value           4
# 96                current  Variable           4
# 97             filehandle  Variable           4
# 100                 named     Value           4
# 101             attribute     Value           4
# 102             directory     Value           4
# 107                EINVAL     Value           4
# 108                <NULL>  Variable           4
# 109            UNCHECKED4  Variable           5
# 172            UNCHECKED4  Variable           8
# 176              existing     Value           8
# 177                  file     Value           8
# 179            attributes  Variable           8
# 182           createattrs     Value           8
# 190                  size  Variable           8
# 192                  zero     Value           8
# 196              existing  Variable           8
# 197                  file  Variable           8
# 202              GUARDED4  Variable           9
# 224             duplicate     Value          10
# 229         NFS4ERR_EXIST     Value          10
# ...                   ...       ...         ...
# 7523           filehandle  Variable         281
# 7533         NFS4ERR_XDEV     Value         281
# 7538               <NULL>  Variable         281
# 7541              current  Variable         282
# 7542           filehandle  Variable         282
# 7555                saved  Variable         282
# 7556           filehandle  Variable         282
# 7570      NFS4ERR_NOTSUPP     Value         282
# 7571               <NULL>  Variable         282
# 7576              newname  Variable         283
# 7586                saved  Variable         283
# 7587           filehandle  Variable         283
# 7592        NFS4ERR_EXIST     Value         283
# 7593               <NULL>  Variable         283
# 7612              current  Variable         284
# 7613           filehandle  Variable         284
# 7615              stateid  Variable         284
# 7616               <NULL>  Variable         284
# 8087        NFS4ERR_INVAL     Value         295
# 8089    NFS4ERR_BAD_RANGE     Value         295
# 8100               <NULL>  Variable         295
# 8102              success     Value         296
# 8104              current  Variable         296
# 8105           filehandle  Variable         296
# 8108                value  Variable         296
# 8109               <NULL>  Variable         296
# 8135   NFS4ERR_LOCK_RANGE     Value         297
# 8136               <NULL>  Variable         297
# 8230               client  Variable         299
# 8233  OPEN_DELEGATE_WRITE     Value         299
#
# [438 rows x 3 columns]

# %%
tags = list(set(df2["tag"].values))

# %%
et = df2['entity']
